# %% [markdown]
# <a href="https://colab.research.google.com/github/pradhumanydv/sem4_algo_lab/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt


def selection_sort(numbers):
    n = len(numbers)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if numbers[j] < numbers[min_index]:
                min_index = j

        numbers[i], numbers[min_index] = numbers[min_index], numbers[i]
    return numbers



n = int(input("Enter number of elements: "))
numbers = []

for i in range(n):
    numbers.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal List:", numbers)

sorted_list = selection_sort(numbers.copy())
print("Sorted List:", sorted_list)


input_sizes = [100, 200, 300, 400, 500]
execution_times = []

for size in input_sizes:
    test_list = [random.randint(1, 1000) for _ in range(size)]

    start_time = time.time()
    selection_sort(test_list)
    end_time = time.time()

    execution_times.append(end_time - start_time)

print("\nInput Sizes:", input_sizes)
print("Execution Times:", execution_times)



plt.plot(input_sizes, execution_times, marker='o', color='blue')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Running Time of Selection Sort")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 10
# Enter element 1: 4
# Enter element 2: 78
# Enter element 3: 45
# Enter element 4: 45
# Enter element 5: 44
# Enter element 6: 544
# Enter element 7: 44
# Enter element 8: 44
# Enter element 9: 44
# Enter element 10: 44
#
# Original List: [4, 78, 45, 45, 44, 544, 44, 44, 44, 44]
# Sorted List: [4, 44, 44, 44, 44, 44, 45, 45, 78, 544]
#
# Input Sizes: [100, 200, 300, 400, 500]
# Execution Times: [0.00026988983154296875, 0.0007927417755126953, 0.0019910335540771484, 0.004259347915649414, 0.0060575008392333984]

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
27#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt


def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2


        left_half = arr[:mid]
        right_half = arr[mid:]


        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0


        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1


        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1



n = int(input("Enter number of elements: "))
arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal List:", arr)

merge_sort(arr)
print("Sorted List:", arr)



input_sizes = [100, 200, 300, 400, 500, 600, 700]
execution_times = []

for size in input_sizes:
    test_list = [random.randint(1, 1000) for _ in range(size)]

    start_time = time.time()
    merge_sort(test_list)
    end_time = time.time()

    execution_times.append(end_time - start_time)

print("\nInput Sizes:", input_sizes)
print("Execution Times:", execution_times)



plt.plot(input_sizes, execution_times, marker='o', color='green')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Merge Sort: Time Taken vs Number of Elements")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 10
# Enter element 1: 45
# Enter element 2: 7
# Enter element 3: 778
# Enter element 4: 4
# Enter element 5: 56
# Enter element 6: 1
# Enter element 7: 12
# Enter element 8: 8
# Enter element 9: 45
# Enter element 10: 15
#
# Original List: [45, 7, 778, 4, 56, 1, 12, 8, 45, 15]
# Sorted List: [1, 4, 7, 8, 12, 15, 45, 45, 56, 778]
#
# Input Sizes: [100, 200, 300, 400, 500, 600, 700]
# Execution Times: [0.00019240379333496094, 0.0003094673156738281, 0.000514984130859375, 0.0006926059722900391, 0.0009098052978515625, 0.0014233589172363281, 0.0012950897216796875]

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
14#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

n = int(input("Enter number of elements: "))
arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal List:", arr)
sorted_arr = quick_sort(arr)
print("Sorted List:", sorted_arr)

input_sizes = [100, 200, 300, 400, 500, 600, 700]
execution_times = []

for size in input_sizes:
    test_list = [random.randint(1, 1000) for _ in range(size)]
    start_time = time.time()
    quick_sort(test_list)
    end_time = time.time()
    execution_times.append(end_time - start_time)

print("\nInput Sizes:", input_sizes)
print("Execution Times:", execution_times)

plt.plot(input_sizes, execution_times, marker='o', color='red')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Quick Sort: Time Taken vs Number of Elements")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 10
# Enter element 1: 78
# Enter element 2: 79
# Enter element 3: 82
# Enter element 4: 5
# Enter element 5: 6
# Enter element 6: 75
# Enter element 7: 45
# Enter element 8: 45
# Enter element 9: 14
# Enter element 10: 444
#
# Original List: [78, 79, 82, 5, 6, 75, 45, 45, 14, 444]
# Sorted List: [5, 6, 14, 45, 45, 75, 78, 79, 82, 444]
#
# Input Sizes: [100, 200, 300, 400, 500, 600, 700]
# Execution Times: [0.00015354156494140625, 0.0002949237823486328, 0.0004565715789794922, 0.0005488395690917969, 0.0008265972137451172, 0.0012559890747070312, 0.0010578632354736328]

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
# Creating a random value (uniform)
import random
import copy
import timeit
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

# %%
a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    if l <= 10000:
        start_time = timeit.default_timer()
        selection_sort(c)
        c_time.append((timeit.default_timer() - start_time) * 1000)
    else:
        c_time.append(None)

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
